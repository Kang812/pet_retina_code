# %%
import json
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("/onetouch/project/pet_retina_develop/data/images/cat/각막궤양/무/crop_C0_3df7b399-60a5-11ec-8402-0a7404972c70.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize = (10,10))
plt.imshow(img)
plt.title("Cat Sample Shape : (%s, %s)" % (img.shape[0], img.shape[1]))
plt.axis("off")
plt.show()

# %%
import json
with open("/mnt/d/project/pet_retina/153.반려동물 안구질환 데이터/01.데이터/sample/crop_C0_3e4a31f5-60a5-11ec-8402-0a7404972c70.json", "r") as f:
    json_data = json.load(f)

json_data.keys()
json_data['images']
# Out:
# {'meta': {'file_name': 'C0_3e4a31f5-60a5-11ec-8402-0a7404972c70.jpg',
#   'date_time': '2016-07-26 00:00:00',
#   'device': '검안경',
#   'gender': 1,
#   'age': 9,
#   'breed': '페르시안',
#   'medical_type': 1,
#   'width_height': [1920, 1372],
#   'eye_position': '오른쪽눈',
#   'image_resolution': [0, 0]}}

# %%
json_data['label']
# Out:
# {'label_filename': 'crop_C0_3e4a31f5-60a5-11ec-8402-0a7404972c70.jpg',
#  'label_category_id': 1,
#  'label_path': '라벨링데이터/안구/고양이/안구/일반/각막부골편/유/crop_C0_3e4a31f5-60a5-11ec-8402-0a7404972c70.jpg',
#  'label_deleted': 0,
#  'label_bbox': [0.0, 0.0, 1920.0, 1372.0],
#  'label_disease_nm': '각막부골편',
#  'label_disease_lv_1': '유',
#  'label_disease_lv_2': '유',
#  'label_disease_lv_3': '유'}

# %%
img.shape
# Out:
# (400, 400, 3)

# %%
import pandas as pd
from glob import glob

image_paths = glob("/mnt/d/project/pet_retina/data/train/cat/*/*/*.jpg") + glob("/mnt/d/project/pet_retina/data/train/cat/*/*/*.png")
print(len(image_paths))
# Out:
# 23012

# %%
json_path = image_paths[0].replace(".jpg", ".json")
print(json_path)
# Out:
# /mnt/d/project/pet_retina/data/train/cat/각막궤양/무/C0_118fec2a-60a5-11ec-8402-0a7404972c70.json

# %%
json_path.split("/")[-2]
# Out:
# '무'

# %%
import json

with open(json_path, "r") as f:
    annotations = json.load(f)

# %%
annotations['images']['meta']
# Out:
# {'file_name': 'C0_118fec2a-60a5-11ec-8402-0a7404972c70.jpg',
#  'date_time': '2020-07-04 00:00:00',
#  'device': '검안경',
#  'gender': 0,
#  'age': 5,
#  'breed': '먼치킨',
#  'medical_type': 1,
#  'width_height': [3264, 2448],
#  'eye_position': '오른쪽눈',
#  'image_resolution': [96, 96]}

# %%
annotations
# Out:
# {'images': {'meta': {'file_name': 'C0_118fec2a-60a5-11ec-8402-0a7404972c70.jpg',
#    'date_time': '2020-07-04 00:00:00',
#    'device': '검안경',
#    'gender': 0,
#    'age': 5,
#    'breed': '먼치킨',
#    'medical_type': 1,
#    'width_height': [3264, 2448],
#    'eye_position': '오른쪽눈',
#    'image_resolution': [96, 96]}}}

# %%
annotations['images']['meta']
# Out:
# {'file_name': 'C0_118fec2a-60a5-11ec-8402-0a7404972c70.jpg',
#  'date_time': '2020-07-04 00:00:00',
#  'device': '검안경',
#  'gender': 0,
#  'age': 5,
#  'breed': '먼치킨',
#  'medical_type': 1,
#  'width_height': [3264, 2448],
#  'eye_position': '오른쪽눈',
#  'image_resolution': [96, 96]}

# %%
if "label" not in list(annotations.keys()):
    label = annotations['images']['meta']['eye_position'] + "_" + "무"
    print(label)
# Out:
# 오른쪽눈_무

# %%
import json
with open("/mnt/d/project/pet_retina/153.반려동물 안구질환 데이터/01.데이터/sample/crop_C0_3e4a31f5-60a5-11ec-8402-0a7404972c70.json", "r") as f:
    json_data = json.load(f)

json_data.keys()
json_data
# Out:
# {'images': {'meta': {'file_name': 'C0_3e4a31f5-60a5-11ec-8402-0a7404972c70.jpg',
#    'date_time': '2016-07-26 00:00:00',
#    'device': '검안경',
#    'gender': 1,
#    'age': 9,
#    'breed': '페르시안',
#    'medical_type': 1,
#    'width_height': [1920, 1372],
#    'eye_position': '오른쪽눈',
#    'image_resolution': [0, 0]}},
#  'label': {'label_filename': 'crop_C0_3e4a31f5-60a5-11ec-8402-0a7404972c70.jpg',
#   'label_category_id': 1,
#   'label_path': '라벨링데이터/안구/고양이/안구/일반/각막부골편/유/crop_C0_3e4a31f5-60a5-11ec-8402-0a7404972c70.jpg',
#   'label_deleted': 0,
#   'label_bbox': [0.0, 0.0, 1920.0, 1372.0],
#   'label_disease_nm': '각막부골편',
#   'label_disease_lv_1': '유',
#   'label_disease_lv_2': '유',
#   'label_disease_lv_3': '유'}}

# %%
if "label" in list(json_data.keys()):
    label = json_data['images']['meta']['eye_position'] + "_" + json_data['label']['label_disease_nm'] + "_유"
    print(label)
# Out:
# 오른쪽눈_각막부골편_유

# %%
import pandas as pd

df = pd.read_csv("/mnt/d/project/pet_retina/data/full_data_frame.csv")

# %%
dieases_cnt = df['label'].value_counts()

# %%
dieases_cnt = dieases_cnt.reset_index()
dieases_cnt
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /mnt/d/project/pet_retina/code/ex.ipynb Cell 18 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/d/project/pet_retina/code/ex.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> dieases_cnt = dieases_cnt.reset_index()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/d/project/pet_retina/code/ex.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> dieases_cnt
#
# File ~/miniconda3/envs/py3.8/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
dieases_cnt.head(10)
# Out:
#    level_0             index  label
# 0        0     dog_왼쪽눈_핵경화_유   6168
# 1        1     dog_왼쪽눈_유루증_유   5231
# 2        2  dog_오른쪽눈_안검내반증_유   5111
# 3        3    dog_오른쪽눈_핵경화_무   4900
# 4        4    dog_오른쪽눈_유루증_무   4885
# 5        5  dog_오른쪽눈_안검내반증_무   4861
# 6        6   dog_왼쪽눈_안검내반증_무   4738
# 7        7     dog_왼쪽눈_유루증_무   4715
# 8        8     dog_왼쪽눈_핵경화_무   4699
# 9        9   dog_왼쪽눈_안검내반증_유   4464

# %%
dieases_cnt.tail(10)
# Out:
#     level_0               index  label
# 30       30       cat_왼쪽눈_결막염_유   1526
# 31       31      cat_왼쪽눈_각막궤양_유   1475
# 32       32  cat_오른쪽눈_비궤양성각막염_유    648
# 33       33  cat_오른쪽눈_비궤양성각막염_무    607
# 34       34   cat_왼쪽눈_비궤양성각막염_무    592
# 35       35   cat_왼쪽눈_비궤양성각막염_유    544
# 36       36      cat_오른쪽눈_안검염_무    495
# 37       37      cat_오른쪽눈_안검염_유    486
# 38       38       cat_왼쪽눈_안검염_무    465
# 39       39       cat_왼쪽눈_안검염_유    457

# %%
dieases_cnt
# Out:
#     level_0               index  label
# 0         0       dog_왼쪽눈_핵경화_유   6168
# 1         1       dog_왼쪽눈_유루증_유   5231
# 2         2    dog_오른쪽눈_안검내반증_유   5111
# 3         3      dog_오른쪽눈_핵경화_무   4900
# 4         4      dog_오른쪽눈_유루증_무   4885
# 5         5    dog_오른쪽눈_안검내반증_무   4861
# 6         6     dog_왼쪽눈_안검내반증_무   4738
# 7         7       dog_왼쪽눈_유루증_무   4715
# 8         8       dog_왼쪽눈_핵경화_무   4699
# 9         9     dog_왼쪽눈_안검내반증_유   4464
# 10       10      dog_오른쪽눈_유루증_유   4370
# 11       11       dog_왼쪽눈_안검염_유   3458
# 12       12      dog_오른쪽눈_안검염_무   3457
# 13       13      dog_오른쪽눈_핵경화_유   3432
# 14       14       dog_왼쪽눈_안검염_무   3422
# 15       15      dog_오른쪽눈_안검염_유   3422
# 16       16     dog_오른쪽눈_안검종양_유   2930
# 17       17     dog_오른쪽눈_안검종양_무   2485
# 18       18      dog_왼쪽눈_안검종양_무   2315
# 19       19      dog_왼쪽눈_안검종양_유   1880
# 20       20     cat_오른쪽눈_각막궤양_유   1652
# 21       21      cat_오른쪽눈_결막염_유   1593
# 22       22     cat_오른쪽눈_각막궤양_무   1575
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

full_df = pd.read_csv("/mnt/d/project/pet_retina/data/full_data_frame.csv")

train, val = train_test_split(full_df, test_size=0.2, stratify=full_df['label'])
val, test = train_test_split(val, test_size=0.5, stratify=val['label'])

# %%
print("train shape:",train.shape)
print("valid shape:",val.shape)
print("test shape:",test.shape)
# Out:
# train shape: (83164, 2)
# valid shape: (10395, 2)
# test shape: (10396, 2)

# %%
train.to_csv("/mnt/d/project/pet_retina/data/train.csv", index = False)
val.to_csv("/mnt/d/project/pet_retina/data/val.csv", index = False)
test.to_csv("/mnt/d/project/pet_retina/data/test.csv", index = False)

# %%
import sys
sys.path.append("/mnt/d/project/pet_retina/utils/")
from dataloader import Pet_Dataset
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
from torchvision.transforms import ToTensor, RandomHorizontalFlip, RandomVerticalFlip

train_df_path = "/mnt/d/project/pet_retina/data/train.csv"

train_transforms= transforms.Compose([
    transforms.Resize(224),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))])

train_dataset = Pet_Dataset(train_df_path, transform =  train_transforms)

image = train_dataset[10][0]
label = train_dataset[10][1]

nump_image = image.detach().cpu().numpy()
nump_image = nump_image.transpose(1,2,0)
print(label)
plt.imshow(nump_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 30

# %%
import sys
sys.path.append("/mnt/d/project/pet_retina/utils/")
from dataloader import pet_dataloader
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
from torchvision.transforms import ToTensor, RandomHorizontalFlip, RandomVerticalFlip


train_df_path = "/mnt/d/project/pet_retina/data/train.csv"

train_transforms= transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))])

shuffle = True
batch_size = 8

train_dataloader = pet_dataloader(df_path = train_df_path, transform = train_transforms, batch_size = batch_size, shuffle = shuffle)

# %%
len(train_dataloader)
# Out:
# 10396

# %%
sampling_data = next(iter(train_dataloader))

sampling_data[0].size()
# Out:
# torch.Size([8, 3, 224, 224])

# %%
import sys
sys.path.append("/mnt/d/project/pet_retina/model/")
from load  import load_model

model_name = 'efficientnet_b0'
pretrained = True
num_classes = 40

net = load_model(model_name, pretrained, num_classes)
# Out:
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-weights/efficientnet_b0_ra-3dd342df.pth" to /home/bgw2001/.cache/torch/hub/checkpoints/efficientnet_b0_ra-3dd342df.pth

# %%
from tqdm import tqdm
import time

pbar = tqdm(total=1000**3, unit='unit', unit_scale=True)
for _ in range(20):
    time.sleep(0.1)
    pbar.update(1)
pbar.close()
# Out:
#   0%|          | 20.0/1.00G [00:02<28093:10:06, 9.89unit/s]

# %%
import torch
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

x = torch.arange(-5, 5, 0.1).view(-1, 1)
y = -5 * x + 0.1 * torch.randn(x.size())

model = torch.nn.Linear(1, 1)
criterion = torch.nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr = 0.1)

def train_model(iter):
    for epoch in range(iter):
        y1 = model(x)
        loss = criterion(y1, y)
        print(loss.)
        writer.add_scalar("Loss/train", loss, epoch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

train_model(10)
writer.flush()
# Out:
# tensor(164.9710, grad_fn=<MseLossBackward0>)
# tensor(73.5158, grad_fn=<MseLossBackward0>)
# tensor(32.7836, grad_fn=<MseLossBackward0>)
# tensor(14.6354, grad_fn=<MseLossBackward0>)
# tensor(6.5449, grad_fn=<MseLossBackward0>)
# tensor(2.9352, grad_fn=<MseLossBackward0>)
# tensor(1.3228, grad_fn=<MseLossBackward0>)
# tensor(0.6015, grad_fn=<MseLossBackward0>)
# tensor(0.2780, grad_fn=<MseLossBackward0>)
# tensor(0.1324, grad_fn=<MseLossBackward0>)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /mnt/d/project/pet_retina/code/ex.ipynb Cell 32 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/d/project/pet_retina/code/ex.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> loss
#
# NameError: name 'loss' is not defined

# %%
import pandas as pd

df = pd.read_csv("/mnt/d/project/pet_retina/data/train.csv")
df.shape
# Out:
# (83164, 2)

# %%
import pandas as pd

df = pd.read_csv("/mnt/d/project/pet_retina/data/val.csv")
df.shape
# Out:
# (10395, 2)

# %%
import pandas as pd

df = pd.read_csv("/mnt/d/project/pet_retina/data/test.csv")
df.shape
# Out:
# (10396, 2)

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
import pandas as pd
import cv2
from tqdm import tqdm

train_df_path = "/mnt/d/project/pet_retina/data/train.csv"
df = pd.read_csv(train_df_path)

# %%
img_paths = df['image_path'].to_list()

for i in tqdm(range(len(img_paths))):
    img = cv2.imread(img_paths[i])
    if img.shape[2] == 1:
        print(img_paths[i])
# Out:
# ...
# 100%|██████████| 83164/83164 [3:03:03<00:00,  7.57it/s]

# %%
img_paths[42214]
# Out:
# '/mnt/d/project/pet_retina/data/train/dog/안검종양/유/D26_34b22906-60a5-11ec-8402-0a7404972c70.jpg'

# %%
img = cv2.imread(img_paths[42215])
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
import matplotlib.pyplot as plt

plt.imshow(img)
# Out:
# Premature end of JPEG file

# %%
img = cv2.imread(img_paths[74498])
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
# Out:
# Premature end of JPEG file

# %%
train_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /mnt/d/project/pet_retina/code/ex.ipynb Cell 42 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/d/project/pet_retina/code/ex.ipynb#X65sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> train_df
#
# NameError: name 'train_df' is not defined

# %%
df[df['image_path'] == img_paths[42215]]
# Out:
#                                               image_path          label
# 42215  /mnt/d/project/pet_retina/data/train/cat/결막염/유...  cat_왼쪽눈_결막염_유

# %%
df[df['image_path'] == img_paths[74498]]
# Out:
#                                               image_path          label
# 74498  /mnt/d/project/pet_retina/data/train/cat/안검염/유...  cat_왼쪽눈_안검염_유

# %%
df = df.drop(42215, axis=0)

# %%
df = df.drop(74498, axis=0)

# %%
df.reset_index(inplace = True, drop = True)

# %%
df.to_csv("/mnt/d/project/pet_retina/data/train.csv", index = False)

# %%
import sys
sys.path.append("/mnt/d/project/pet_retina/utils/")
from dataloader import Pet_Dataset, pet_dataloader
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
import albumentations as A
from albumentations.pytorch import ToTensorV2
#from torchvision.transforms import ToTensor, RandomHorizontalFlip, RandomVerticalFlip

train_df_path = "/mnt/d/project/pet_retina/data/train.csv"

train_transforms= A.Compose([
    A.Resize(224, 224),
    A.HorizontalFlip(0.5),
    A.VerticalFlip(0.5),
    A.transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
    A.pytorch.ToTensorV2()])

dataloader = pet_dataloader(df_path = train_df_path, transform = train_transforms, batch_size = 8, shuffle = True)
a = next(iter(dataloader))

# %%
import cv2
import pandas as pd

df = pd.read_csv(train_df_path)
img_paths = df['image_path']
img = cv2.imread(img_paths[42215])
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

asd = train_transforms(image = img)

# %%
import torchvision.transforms as transforms
import pandas as pd
from PIL import Image
from tqdm import tqdm

train_transforms = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    #transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

train_df_path = "/mnt/d/project/pet_retina/data/train.csv"
df = pd.read_csv(train_df_path)
image_paths = df.image_path

for i in tqdm(range(len(image_paths))):
    img = Image.open(image_paths[i])
    img = train_transforms(img)
    
    if img.size()[0] == 1:
        print(image_paths[i])
# Out:
#  41%|████      | 33681/83162 [42:03<1:02:49, 13.13it/s]
# /mnt/d/project/pet_retina/data/train/cat/결막염/유/C24_11ea9302-60a5-11ec-8402-0a7404972c70.png
# 100%|██████████| 83162/83162 [1:43:55<00:00, 13.34it/s]

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("/mnt/d/project/pet_retina/data/train/cat/결막염/유/C24_11ea9302-60a5-11ec-8402-0a7404972c70.png")
print(img.shape)
plt.imshow(img)
# Out:
# (480, 593, 3)

# %%
import numpy as np
problem_img = np.array(Image.open("/mnt/d/project/pet_retina/data/train/cat/결막염/유/C24_11ea9302-60a5-11ec-8402-0a7404972c70.png"))
problem_img.shape
# Out:
# (480, 593)

# %%
import pandas as pd

train_df_path = "/mnt/d/project/pet_retina/data/train.csv"
df = pd.read_csv(train_df_path)

print(df.shape)
df.head()
# Out:
# (83162, 2)
#                                           image_path            label
# 0  /mnt/d/project/pet_retina/data/train/dog/안검염/유...   dog_오른쪽눈_안검염_유
# 1  /mnt/d/project/pet_retina/data/train/dog/핵경화/무...   dog_오른쪽눈_핵경화_무
# 2  /mnt/d/project/pet_retina/data/train/dog/핵경화/무...    dog_왼쪽눈_핵경화_무
# 3  /mnt/d/project/pet_retina/data/train/dog/안검내반증...  dog_왼쪽눈_안검내반증_유
# 4  /mnt/d/project/pet_retina/data/train/dog/유루증/유...    dog_왼쪽눈_유루증_유

# %%
new_df = df[df['image_path'] != "/mnt/d/project/pet_retina/data/train/cat/결막염/유/C24_11ea9302-60a5-11ec-8402-0a7404972c70.png"]
new_df.shape
new_df.reset_index(drop=True, inplace=True)
new_df.to_csv("/mnt/d/project/pet_retina/data/train_2.csv", index = False)

# %%
import pandas as pd

df = pd.read_csv("/mnt/d/project/pet_retina_develop/data/cat_full_dataframe.csv")

# %%
df['label'].value_counts()
# Out:
# 각막궤양_유       3127
# 결막염_무        3120
# 각막부골편_무      3119
# 결막염_유        3119
# 각막궤양_무       3118
# 각막부골편_유      3115
# 비궤양성각막염_무    1199
# 비궤양성각막염_유    1192
# 안검염_무         960
# 안검염_유         943
# Name: label, dtype: int64

# %%
"안검염_유", "안검염_무"
"비궤양성각막염_무", "비궤양성각막염_유"

# %%
import timm
import torch
import torch.nn as nn

class network(nn.Module):
    def __init__(self, model_name, pretrained, num_classes):
        super(network, self).__init__()
        self.num_classes = num_classes
        self.model_name = model_name
        self.pretrained = pretrained
        self.model = timm.create_model(self.model_name, pretrained=self.pretrained, num_classes = self.num_classes)

    def forward(self, x):
        x = self.model(x)
        return x

# %%
model = network(model_name = 'efficientnet_b0',pretrained = False, num_classes = 2)

# %%
model.load_state_dict(torch.load("/mnt/d/project/pet_retina_develop/work_dir/best.pt"))
model.eval()
# Out:
# network(
#   (model): EfficientNet(
#     (conv_stem): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNormAct2d(
#       32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#       (drop): Identity()
#       (act): SiLU(inplace=True)
#     )
#     (blocks): Sequential(
#       (0): Sequential(
#         (0): DepthwiseSeparableConv(
#           (conv_dw): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn1): BatchNormAct2d(
#             32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): SiLU(inplace=True)
#           )
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (gate): Sigmoid()
#           )
# ...

# %%
import cv2
import numpy as np
import torchvision.transforms as transforms
import torch
from torch.optim import lr_scheduler
from PIL import Image

img = Image.open("/mnt/d/project/pet_retina_develop/data/images/cat/결막염/유/crop_C0_0ec2d16c-60a5-11ec-8402-0a7404972c70.jpg")

val_transforms= transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

img_t = val_transforms(img)
img_t = img_t.unsqueeze(0)

# %%
img_t.size()
# Out:
# torch.Size([1, 3, 224, 224])

# %%
output = model(img_t)

# %%
_, preds = torch.max(output, 1)

# %%
preds
# Out:
# tensor([1])

# %%
output
# Out:
# tensor([[3.5536, 9.5550]], grad_fn=<AddmmBackward0>)

# %%
import torch
import torchvision
from torch.utils.mobile_optimizer import optimize_for_mobile

# %%
#example = torch.rand(1, 3, 224, 224)
traced_script_module = torch.jit.trace(model, img_t)
traced_script_module_optimized = optimize_for_mobile(traced_script_module)
traced_script_module_optimized._save_for_lite_interpreter("/mnt/d/project/pet_retina_develop/work_dir/결막염/mobile_model.ptl")

# %%
## 결막염
import pandas as pd
from tqdm import tqdm

def path_change(df):
    new_paths = []
    img_path = df['image_path'].to_list()
    for i in tqdm(range(len(img_path))):
        new_path = img_path[i].replace("/mnt/d/","/onetouch/")
        new_paths.append(new_path)
    
    df['image_path'] = new_paths
    return df
# Out:
# ...
# 100%|██████████| 624/624 [00:00<00:00, 738083.95it/s]

# %%
## 결막염

train_df = pd.read_csv("/onetouch/project/pet_retina_develop/data/cat_train_conjunctivitis.csv")
val_df = pd.read_csv("/onetouch/project/pet_retina_develop/data/cat_val_conjunctivitis.csv")
test_df = pd.read_csv("/onetouch/project/pet_retina_develop/data/cat_test_conjunctivitis.csv")

train_df = path_change(train_df)
val_df = path_change(val_df)
test_df = path_change(test_df)

train_df.to_csv("/onetouch/project/pet_retina_develop/data/cat_train_conjunctivitis.csv", index=False)
val_df.to_csv("/onetouch/project/pet_retina_develop/data/cat_val_conjunctivitis.csv", index=False)
test_df.to_csv("/onetouch/project/pet_retina_develop/data/cat_test_conjunctivitis.csv", index=False)
# Out:
# ...
# 100%|██████████| 624/624 [00:00<00:00, 891432.46it/s]

# %%
##  각막궤양
train_path = "/onetouch/project/pet_retina_develop/data/cat_train_corneal_ulcer.csv"
val_path = "/onetouch/project/pet_retina_develop/data/cat_val_corneal_ulcer.csv"
test_path = "/onetouch/project/pet_retina_develop/data/cat_test_corneal_ulcer.csv"

train_df = pd.read_csv(train_path)
val_df = pd.read_csv(val_path)
test_df = pd.read_csv(test_path)

train_df = path_change(train_df)
val_df = path_change(val_df)
test_df = path_change(test_df)

train_df.to_csv(train_path, index=False)
val_df.to_csv(val_path, index=False)
test_df.to_csv(test_path, index=False)
# Out:
# ...
# 100%|██████████| 625/625 [00:00<00:00, 739683.97it/s]

# %%
##  각막부골편
train_path = "/onetouch/project/pet_retina_develop/data/cat_train_feline_corneal_sequesration.csv"
val_path = "/onetouch/project/pet_retina_develop/data/cat_val_feline_corneal_sequesration.csv"
test_path = "/onetouch/project/pet_retina_develop/data/cat_test_feline_corneal_sequesration.csv"

train_df = pd.read_csv(train_path)
val_df = pd.read_csv(val_path)
test_df = pd.read_csv(test_path)

train_df = path_change(train_df)
val_df = path_change(val_df)
test_df = path_change(test_df)

train_df.to_csv(train_path, index=False)
val_df.to_csv(val_path, index=False)
test_df.to_csv(test_path, index=False)
# Out:
# ...
# 100%|██████████| 624/624 [00:00<00:00, 737252.31it/s]

# %%
##  안검염
train_path = "/onetouch/project/pet_retina_develop/data/cat_train_meibomian_gland.csv"
val_path = "/onetouch/project/pet_retina_develop/data/cat_val_meibomian_gland.csv"
test_path = "/onetouch/project/pet_retina_develop/data/cat_test_meibomian_gland.csv"

train_df = pd.read_csv(train_path)
val_df = pd.read_csv(val_path)
test_df = pd.read_csv(test_path)

train_df = path_change(train_df)
val_df = path_change(val_df)
test_df = path_change(test_df)

train_df.to_csv(train_path, index=False)
val_df.to_csv(val_path, index=False)
test_df.to_csv(test_path, index=False)
# Out:
# ...
# 100%|██████████| 191/191 [00:00<00:00, 609210.70it/s]

# %%
# 비궤양성각막염
train_path = "/onetouch/project/pet_retina_develop/data/cat_train_non_ulcerative_corn_disease.csv"
val_path = "/onetouch/project/pet_retina_develop/data/cat_val_non_ulcerative_corn_disease.csv"
test_path = "/onetouch/project/pet_retina_develop/data/cat_test_non_ulcerative_corn_disease.csv"

train_df = pd.read_csv(train_path)
val_df = pd.read_csv(val_path)
test_df = pd.read_csv(test_path)

train_df = path_change(train_df)
val_df = path_change(val_df)
test_df = path_change(test_df)

train_df.to_csv(train_path, index=False)
val_df.to_csv(val_path, index=False)
test_df.to_csv(test_path, index=False)
# Out:
# ...
# 100%|██████████| 240/240 [00:00<00:00, 657500.30it/s]

# %%
import pandas as pd

test_df = pd.read_csv('/onetouch/project/pet_retina_develop/data/cat_test_conjunctivitis.csv')
test_df.shape
# Out:
# (624, 2)

# %%
test_df.iloc[1]['image_path']
test_df.iloc[1]['label']
# Out:
# '결막염_유'

# %%
label_seq = {'각막궤양_무': 0, '각막궤양_유': 1}
encoder = dict()

for it in label_seq.items():
   encoder[str(it[1])] = it[0]
len(encoder)
# Out:
# 2

# %%
encoder['0']
# Out:
# '각막궤양_무'

# %%
class_per_acc = dict()

for i in range(len(encoder)):
    class_per_acc[encoder[str(i)]] = 0
class_per_acc
# Out:
# {'각막궤양_무': 0, '각막궤양_유': 0}

# %%
for i in label_seq.keys():
    print(i)
# Out:
# 각막궤양_무
# 각막궤양_유
